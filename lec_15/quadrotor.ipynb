# %%
import Pkg; Pkg.activate(@__DIR__); Pkg.instantiate()
# Out:
#   Activating environment at `~/Documents/Study/Robotics/optimal_control_julia/lec_15/Project.toml`
# Precompiling project...
#   ✓ EnumX
#   ✓ MuladdMacro
#   ✓ ExprTools
#   ✓ ManualMemory
#   ✓ FastClosures
#   ✓ IfElse
#   ✓ Inflate
#   ✓ Richardson
#   ✓ CpuId
#   ✓ SimpleUnPack
#   ✓ SIMDTypes
#   ✓ Hungarian
#   ✓ Functors
#   ✓ FunctionWrappers
#   ✓ GenericSchur
#   ✓ MakieCore
#   ✓ Rmath_jll
#   ✓ SnoopPrecompile
#   ✓ libblastrampoline_jll
#   ✓ DensityInterface
#   ✓ CommonSolve
#   ✓ PDMats
#   ✓ Calculus
#   ✓ PrecompileTools
#   ✓ FillArrays
#   ✓ OpenBLAS_jll
#   ✓ FastLapackInterface
#   ✓ IntelOpenMP_jll
#   ✓ Distances
#   ✓ Libmount_jll
#   ✓ RuntimeGeneratedFunctions
#   ✓ FFTW_jll
#   ✓ FunctionWrappersWrappers
#   ✓ ThreadingUtilities
#   ✓ ZygoteRules
#   ✓ SimpleTraits
#   ✓ Sparspak
#   ✓ Static
#   ✓ QuadGK
#   ✓ AbstractFFTs
#   ✓ Rmath
#   ✓ SuiteSparse_jll
#   ✓ LinearMaps
#   ✓ ArrayInterfaceCore
#   ✓ BitTwiddlingConvenienceFunctions
#   ✓ MKL_jll
#   ✓ HTTP
#   ✓ KrylovKit
#   ✓ ArrayInterfaceGPUArrays
#   ✓ CPUSummary
#   ✓ KLU
#   ✓ ArrayInterfaceStaticArraysCore
#   ✓ RecipesBase
#   ✓ HostCPUFeatures
#   ✓ WebSockets
#   ✓ PolyesterWeave
#   ✓ ArrayInterface
#   ✓ CloseOpenIntervals
#   ✓ Glib_jll
#   ✓ IterativeSolvers
#   ✓ StatsBase
#   ✓ ArrayInterfaceOffsetArrays
#   ✓ MatrixEquations
#   ✓ Cairo_jll
#   ✓ Krylov
#   ✓ HarfBuzz_jll
#   ✓ RecursiveArrayTools
#   ✓ FFTW
#   ✓ libass_jll
#   ✓ FFMPEG_jll
#   ✓ FFMPEG
#   ✓ DualNumbers
#   ✓ StaticArrays
#   ✓ HypergeometricFunctions
#   ✓ ArrayInterfaceStaticArrays
#   ✓ FiniteDiff
#   ✓ FiniteDifferences
#   ✓ SciMLBase
#   ✓ StructArrays
#   ✓ CoordinateTransformations
#   ✓ ArnoldiMethod
#   ✓ LayoutPointers
#   ✓ StatsFuns
#   ✓ Rotations
#   ✓ BlockDiagonals
#   ✓ ForwardDiff
#   ✓ Parsers
#   ✓ JSON
#   ✓ AssetRegistry
#   ✓ StrideArraysCore
#   ✓ BenchmarkTools
#   ✓ PreallocationTools
#   ✓ NLSolversBase
#   ✓ Mux
#   ✓ Graphs
#   ✓ WebIO
#   ✓ Polyester
#   ✓ GeometryBasics
#   ✓ VertexSafeGraphs
#   ✓ Polynomials
#   ✓ SimpleNonlinearSolve
#   ✓ JSExpr
#   ✓ LineSearches
#   ✓ FastBroadcast
#   ✓ MeshIO
#   ✓ SparseDiffTools
#   ✓ Distributions
#   ✓ Blink
#   ✓ NLsolve
#   ✓ MatrixPencils
#   ✓ DSP
#   ✓ ExponentialUtilities
#   ✓ RobotDynamics
#   ✓ MeshCat
#   ✓ MathOptInterface
#   ✓ RobotZoo
#   ✓ VectorizationBase
#   ✓ DiffEqBase
#   ✓ TrajectoryOptimization
#   ✓ SLEEFPirates
#   ✓ DiffEqCallbacks
#   ✓ TrajOptPlots
#   ✓ LoopVectorization
#   ✓ ControlSystemsBase
#   ✓ TriangularSolve
#   ✓ RecursiveFactorization
#   ✓ LinearSolve
#   ✓ OrdinaryDiffEq
#   ✓ DelayDiffEq
#   ✓ ControlSystems
#   130 dependencies successfully precompiled in 382 seconds (102 already precompiled)
#   3 dependencies precompiled but different versions are currently loaded. Restart julia to access the new versions

# %%
using LinearAlgebra
using ForwardDiff
using BlockDiagonals
using ControlSystems
# Out:
# [ Info: Precompiling ForwardDiff [f6369f11-7733-5829-9624-2563aa707210]
# [ Info: Precompiling BlockDiagonals [0a1fb500-61f7-11e9-3c65-f5ef3456f9f0]
# [ Info: Precompiling ControlSystems [a6e380b2-a6ca-5380-bf3e-84a91bcd477e]
# WARNING: could not import LinearAlgebra.libblastrampoline into LapackUtil2
# ┌ Warning: Replacing docs for `SciMLBase.sol :: Union{Tuple, Tuple{D}, Tuple{S}, Tuple{N}, Tuple{T}} where {T, N, S, D}` in module `SciMLBase`
# └ @ Base.Docs docs/Docs.jl:240
# ┌ Warning: The call to compilecache failed to create a usable precompiled cache file for OrdinaryDiffEq [1dea7af3-3e70-54e6-95c3-0bf5283fa5ed]
# │   exception = Required dependency LoopVectorization [bdcacae8-1622-11e9-2a5c-532679323890] failed to load from a cache file.
# └ @ Base loading.jl:1055
# ┌ Warning: Module ArrayInterfaceCore with build ID 44766920394779198 is missing from the cache.
# │ This may mean ArrayInterfaceCore [30b0a656-2188-435a-8636-2ec0e6a096e2] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module ArrayInterfaceCore with build ID 44766920394779198 is missing from the cache.
# │ This may mean ArrayInterfaceCore [30b0a656-2188-435a-8636-2ec0e6a096e2] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module ArrayInterfaceCore with build ID 44766920394779198 is missing from the cache.
# │ This may mean ArrayInterfaceCore [30b0a656-2188-435a-8636-2ec0e6a096e2] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module ArrayInterfaceCore with build ID 44766920394779198 is missing from the cache.
# │ This may mean ArrayInterfaceCore [30b0a656-2188-435a-8636-2ec0e6a096e2] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module ArrayInterfaceCore with build ID 44766920394779198 is missing from the cache.
# │ This may mean ArrayInterfaceCore [30b0a656-2188-435a-8636-2ec0e6a096e2] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module ArrayInterfaceCore with build ID 44766920394779198 is missing from the cache.
# │ This may mean ArrayInterfaceCore [30b0a656-2188-435a-8636-2ec0e6a096e2] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module ArrayInterfaceCore with build ID 44766920394779198 is missing from the cache.
# │ This may mean ArrayInterfaceCore [30b0a656-2188-435a-8636-2ec0e6a096e2] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Replacing docs for `SciMLBase.sol :: Union{Tuple, Tuple{D}, Tuple{S}, Tuple{N}, Tuple{T}} where {T, N, S, D}` in module `SciMLBase`
# └ @ Base.Docs docs/Docs.jl:240
# ┌ Warning: Module ArrayInterfaceCore with build ID 44766920394779198 is missing from the cache.
# │ This may mean ArrayInterfaceCore [30b0a656-2188-435a-8636-2ec0e6a096e2] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module SpecialFunctions with build ID 44766874858009810 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module SpecialFunctions with build ID 44766874858009810 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module SpecialFunctions with build ID 44766874858009810 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module SpecialFunctions with build ID 44766874858009810 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module SpecialFunctions with build ID 44766874858009810 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module SpecialFunctions with build ID 44766874858009810 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module ArrayInterfaceCore with build ID 44766920394779198 is missing from the cache.
# │ This may mean ArrayInterfaceCore [30b0a656-2188-435a-8636-2ec0e6a096e2] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module ArrayInterface with build ID 44766919924210112 is missing from the cache.
# │ This may mean ArrayInterface [4fba245c-0d91-5ea0-9b3e-6abc04ee57a9] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module VectorizationBase with build ID 44767397537351396 is missing from the cache.
# │ This may mean VectorizationBase [3d5dd08c-fd9d-11e8-17fa-ed2836048c2f] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module ArrayInterfaceCore with build ID 44766920394779198 is missing from the cache.
# │ This may mean ArrayInterfaceCore [30b0a656-2188-435a-8636-2ec0e6a096e2] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module LoopVectorization with build ID 44767397030812091 is missing from the cache.
# │ This may mean LoopVectorization [bdcacae8-1622-11e9-2a5c-532679323890] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module LayoutPointers with build ID 44766923395182041 is missing from the cache.
# │ This may mean LayoutPointers [10f19ff3-798f-405d-979b-55457f8fc047] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module ForwardDiff with build ID 44766874405894629 is missing from the cache.
# │ This may mean ForwardDiff [f6369f11-7733-5829-9624-2563aa707210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module ArrayInterfaceCore with build ID 44766920394779198 is missing from the cache.
# │ This may mean ArrayInterfaceCore [30b0a656-2188-435a-8636-2ec0e6a096e2] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module ArrayInterfaceCore with build ID 44766920394779198 is missing from the cache.
# │ This may mean ArrayInterfaceCore [30b0a656-2188-435a-8636-2ec0e6a096e2] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module FiniteDiff with build ID 44767371369907462 is missing from the cache.
# │ This may mean FiniteDiff [6a86dc24-6348-571c-b903-95158fe2bd41] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module FiniteDiff with build ID 44767371369907462 is missing from the cache.
# │ This may mean FiniteDiff [6a86dc24-6348-571c-b903-95158fe2bd41] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module FiniteDiff with build ID 44767371369907462 is missing from the cache.
# │ This may mean FiniteDiff [6a86dc24-6348-571c-b903-95158fe2bd41] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module NLSolversBase with build ID 44767492694400271 is missing from the cache.
# │ This may mean NLSolversBase [d41bc354-129a-5804-8e4c-c37616107c6c] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module FiniteDiff with build ID 44767371369907462 is missing from the cache.
# │ This may mean FiniteDiff [6a86dc24-6348-571c-b903-95158fe2bd41] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030

# %%
#Quaternion stuff
function hat(v)
    return [0 -v[3] v[2];
            v[3] 0 -v[1];
            -v[2] v[1] 0]
end
function L(q)
    s = q[1]
    v = q[2:4]
    L = [s    -v';
         v  s*I+hat(v)]
    return L
end
T = Diagonal([1; -ones(3)])
H = [zeros(1,3); I]
function qtoQ(q)
    return H'*T*L(q)*T*L(q)*H
end
function G(q)
    G = L(q)*H
end
function rptoq(ϕ)
    (1/sqrt(1+ϕ'*ϕ))*[1; ϕ]
end
function qtorp(q)
    q[2:4]/q[1]
end

# %%
#Quadrotor parameters
m = 0.5
ℓ = 0.1750
J = Diagonal([0.0023, 0.0023, 0.004])
g = 9.81
kt=1.0
km=0.0245

h = 0.05 #20 Hz

Nx = 13     # number of states (quaternion)
Nx̃ = 12     # number of states (linearized)
Nu = 4     # number of controls
Tfinal = 5.0 # final time
Nt = Int(Tfinal/h)+1    # number of time steps
thist = Array(range(0,h*(Nt-1), step=h));

# %%
function E(q)
    E = BlockDiagonal([1.0*I(3), G(q), 1.0*I(6)])
end

# %%
function quad_dynamics(x,u)
    r = x[1:3]
    q = x[4:7]/norm(x[4:7]) #normalize q just to be careful
    v = x[8:10]
    ω = x[11:13]
    Q = qtoQ(q)
    
    ṙ = Q*v
    q̇ = 0.5*L(q)*H*ω
    
    v̇ = Q'*[0; 0; -g] + (1/m)*[zeros(2,4); kt*ones(1,4)]*u - hat(ω)*v
    
    ω̇ = J\(-hat(ω)*J*ω + [0 ℓ*kt 0 -ℓ*kt; -ℓ*kt 0 ℓ*kt 0; km -km km -km]*u)
    
    return [ṙ; q̇; v̇; ω̇]
end

# %%
function quad_dynamics_rk4(x,u)
    #RK4 integration with zero-order hold on u
    f1 = quad_dynamics(x, u)
    f2 = quad_dynamics(x + 0.5*h*f1, u)
    f3 = quad_dynamics(x + 0.5*h*f2, u)
    f4 = quad_dynamics(x + h*f3, u)
    xn = x + (h/6.0)*(f1 + 2*f2 + 2*f3 + f4)
    xn[4:7] .= xn[4:7]/norm(xn[4:7]) #re-normalize quaternion
    return xn
end

# %%
#Initial Conditions
uhover = (m*g/4)*ones(4)
r0 = [0.0; 0; 1.0]
q0 = [1.0; 0; 0; 0]
v0 = zeros(3)
ω0 = zeros(3)
x0 = [r0; q0; v0; ω0];

# %%
#Linearize dynamics about hover
A = ForwardDiff.jacobian(x->quad_dynamics_rk4(x,uhover),x0)
B = ForwardDiff.jacobian(u->quad_dynamics_rk4(x0,u),uhover);

# %%
rank(A)#The naive A matrix will always be rank deficient due to the unit-norm constraint on the quaternion

# %%
#Controlability Matrix
C = B
for k = 1:(Nx-1)
    C = [C A*C[:,end-(Nu-1):end]]
end

# %%
rank(C) #The naive linearized system will always be uncontrollable

# %%
#Reduced system
Ã = Array(E(q0)'*A*E(q0))
B̃ = Array(E(q0)'*B);

# %%
#Controlability Matrix
C = B̃
for k = 1:(Nx-1)
    C = [C Ã*C[:,end-(Nu-1):end]]
end

# %%
rank(C) #Reduced system is controllable

# %%
# Cost weights
Q = Array(I(Nx̃));
R = Array(.1*I(Nu));

# %%
#LQR Controller
K = dlqr(Ã,B̃,Q,R)

# %%
#Feedback controller
function controller(x)
    
    q0 = x0[4:7]
    q = x[4:7]
    ϕ = qtorp(L(q0)'*q)
    
    Δx̃ = [x[1:3]-r0; ϕ; x[8:10]-v0; x[11:13]-ω0]
    
    u = uhover - K*Δx̃
end

# %%
#Simulation
uhist = zeros(Nu,Nt)
xhist = zeros(Nx,Nt)
xhist[:,1] = [r0+randn(3); L(q0)*rptoq([1; 0; 0]); v0; ω0]
for k = 1:(Nt-1)
    uhist[:,k] = controller(xhist[:,k])
    xhist[:,k+1] = quad_dynamics_rk4(xhist[:,k],uhist[:,k])
end

# %%
#Set up visualization
using TrajOptPlots
using MeshCat
using StaticArrays
using RobotZoo:Quadrotor

vis = Visualizer()
render(vis)

# %%
model = Quadrotor()
TrajOptPlots.set_mesh!(vis, model)

# %%
X1 = [SVector{13}(x) for x in eachcol(xhist)];
visualize!(vis, model, thist[end], X1)
